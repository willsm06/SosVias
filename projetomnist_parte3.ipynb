# %% [markdown]
# <a href="https://colab.research.google.com/github/willsm06/SosVias/blob/main/projetomnist_parte3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Carregar o modelo salvo
modelo = load_model('modelo_mnist.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Definir o caminho da imagem
caminho_imagem = os.path.join("Digito Teste", "sete.jpg")

imagem = load_img(caminho_imagem)

# Exibir a imagem
plt.figure(figsize=(4, 4))
plt.imshow(imagem)
plt.title("Imagem Importada")
plt.axis("off")  # Ocultar os eixos
plt.show()

# %%
print(f"Modo da imagem: {imagem.mode}")
print(f"Tamanho da imagem: {imagem.size}")
# Out:
# Modo da imagem: RGB
# Tamanho da imagem: (300, 300)

# %%
imagem_cinza = imagem.convert("L")  # Converte para modo 'L'

imagem_cinza = imagem_cinza.resize((28, 28))

imagem_array = img_to_array(imagem_cinza)

print(f"Formato da imagem: {imagem_array.shape}")

# Exibir a imagem
plt.figure(figsize=(4, 4))
plt.imshow(imagem_array)
plt.title("Imagem Importada")
plt.axis("off")  # Ocultar os eixos
plt.show()

# Imprimir os valores numéricos da matriz da imagem
print("Matriz da Imagem (valores numéricos):")
print(imagem_array.squeeze())
# Out:
# Formato da imagem: (28, 28, 1)
# Matriz da Imagem (valores numéricos):
# [[194. 193. 191. 193. 192. 192. 194. 194. 192. 193. 193. 192. 194. 193.
#   193. 191. 192. 193. 192. 189. 191. 187. 189. 189. 192. 193. 191. 187.]
#  [192. 191. 191. 192. 193. 193. 191. 194. 194. 194. 194. 192. 194. 193.
#   192. 193. 192. 192. 191. 191. 192. 191. 191. 190. 191. 193. 191. 190.]
#  [192. 190. 192. 192. 192. 194. 194. 194. 194. 195. 191. 193. 194. 193.
#   193. 195. 193. 190. 190. 193. 193. 191. 192. 194. 192. 194. 191. 191.]
#  [192. 192. 192. 192. 192. 194. 194. 192. 192. 194. 193. 194. 195. 192.
#   195. 195. 193. 193. 195. 195. 192. 191. 193. 192. 192. 192. 191. 190.]
#  [190. 191. 191. 192. 191. 193. 194. 193. 192. 194. 196. 193. 194. 197.
#   198. 199. 192. 178. 164. 180. 194. 194. 195. 195. 192. 191. 191. 187.]
#  [190. 190. 187. 191. 190. 193. 191. 194. 196. 195. 195. 119.  96. 158.
#   130. 109.  92.  67.  45.  96. 195. 194. 195. 195. 192. 192. 190. 186.]
# ...

# %%
imagem_array /= 255.0  # Normalizar para [0, 1]

# Exibir a imagem
plt.figure(figsize=(4, 4))
plt.imshow(imagem_array)
plt.title("Imagem Importada")
plt.axis("off")  # Ocultar os eixos
plt.show()

# Imprimir os valores numéricos da matriz da imagem
print("Matriz da Imagem (valores numéricos):")
print(imagem_array.squeeze())
# Out:
# Matriz da Imagem (valores numéricos):
# [[0.7607843  0.75686276 0.7490196  0.75686276 0.7529412  0.7529412
#   0.7607843  0.7607843  0.7529412  0.75686276 0.75686276 0.7529412
#   0.7607843  0.75686276 0.75686276 0.7490196  0.7529412  0.75686276
#   0.7529412  0.7411765  0.7490196  0.73333335 0.7411765  0.7411765
#   0.7529412  0.75686276 0.7490196  0.73333335]
#  [0.7529412  0.7490196  0.7490196  0.7529412  0.75686276 0.75686276
#   0.7490196  0.7607843  0.7607843  0.7607843  0.7607843  0.7529412
#   0.7607843  0.75686276 0.7529412  0.75686276 0.7529412  0.7529412
#   0.7490196  0.7490196  0.7529412  0.7490196  0.7490196  0.74509805
#   0.7490196  0.75686276 0.7490196  0.74509805]
#  [0.7529412  0.74509805 0.7529412  0.7529412  0.7529412  0.7607843
#   0.7607843  0.7607843  0.7607843  0.7647059  0.7490196  0.75686276
#   0.7607843  0.75686276 0.75686276 0.7647059  0.75686276 0.74509805
#   0.74509805 0.75686276 0.75686276 0.7490196  0.7529412  0.7607843
# ...

# %%
# Exibir a imagem em escala de cinza
plt.figure(figsize=(4, 4))
plt.imshow(imagem_array.squeeze(), cmap="gray")  # Usar cmap="gray" para escala de cinza
plt.title("Imagem em Escala de Cinza")
plt.axis("off")  # Ocultar os eixos
plt.show()

# Imprimir os valores numéricos da matriz da imagem
print("Matriz da Imagem (valores numéricos):")
print(imagem_array.squeeze())
# Out:
# Matriz da Imagem (valores numéricos):
# [[0.7607843  0.75686276 0.7490196  0.75686276 0.7529412  0.7529412
#   0.7607843  0.7607843  0.7529412  0.75686276 0.75686276 0.7529412
#   0.7607843  0.75686276 0.75686276 0.7490196  0.7529412  0.75686276
#   0.7529412  0.7411765  0.7490196  0.73333335 0.7411765  0.7411765
#   0.7529412  0.75686276 0.7490196  0.73333335]
#  [0.7529412  0.7490196  0.7490196  0.7529412  0.75686276 0.75686276
#   0.7490196  0.7607843  0.7607843  0.7607843  0.7607843  0.7529412
#   0.7607843  0.75686276 0.7529412  0.75686276 0.7529412  0.7529412
#   0.7490196  0.7490196  0.7529412  0.7490196  0.7490196  0.74509805
#   0.7490196  0.75686276 0.7490196  0.74509805]
#  [0.7529412  0.74509805 0.7529412  0.7529412  0.7529412  0.7607843
#   0.7607843  0.7607843  0.7607843  0.7647059  0.7490196  0.75686276
#   0.7607843  0.75686276 0.75686276 0.7647059  0.75686276 0.74509805
#   0.74509805 0.75686276 0.75686276 0.7490196  0.7529412  0.7607843
# ...

# %%
# Adicionar uma dimensão para representar o batch
imagem_array = imagem_array.reshape(1, 28, 28, 1)

# Fazer a predição
predicao = modelo.predict(imagem_array)

# Obter o rótulo predito
label_predito = np.argmax(predicao)

# Exibir os resultados
print(f"Predição (valores das probabilidades): {predicao}")
print(f"Rótulo predito: {label_predito}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Predição (valores das probabilidades): [[0.07571725 0.00517027 0.2392155  0.0797224  0.083431   0.01438826
#   0.00764697 0.22575141 0.22887681 0.04008014]]
# Rótulo predito: 2

# %%
imagem_array = 1 - imagem_array

# Exibir a imagem em escala de cinza
plt.figure(figsize=(4, 4))
plt.imshow(imagem_array.squeeze(), cmap="gray")  # Usar cmap="gray" para escala de cinza
plt.title("Imagem em Escala de Cinza")
plt.axis("off")  # Ocultar os eixos
plt.show()

# Imprimir os valores numéricos da matriz da imagem
print("Matriz da Imagem (valores numéricos):")
print(imagem_array.squeeze())
# Out:
# Matriz da Imagem (valores numéricos):
# [[0.23921567 0.24313724 0.25098038 0.24313724 0.24705881 0.24705881
#   0.23921567 0.23921567 0.24705881 0.24313724 0.24313724 0.24705881
#   0.23921567 0.24313724 0.24313724 0.25098038 0.24705881 0.24313724
#   0.24705881 0.2588235  0.25098038 0.26666665 0.2588235  0.2588235
#   0.24705881 0.24313724 0.25098038 0.26666665]
#  [0.24705881 0.25098038 0.25098038 0.24705881 0.24313724 0.24313724
#   0.25098038 0.23921567 0.23921567 0.23921567 0.23921567 0.24705881
#   0.23921567 0.24313724 0.24705881 0.24313724 0.24705881 0.24705881
#   0.25098038 0.25098038 0.24705881 0.25098038 0.25098038 0.25490195
#   0.25098038 0.24313724 0.25098038 0.25490195]
#  [0.24705881 0.25490195 0.24705881 0.24705881 0.24705881 0.23921567
#   0.23921567 0.23921567 0.23921567 0.2352941  0.25098038 0.24313724
#   0.23921567 0.24313724 0.24313724 0.2352941  0.24313724 0.25490195
#   0.25490195 0.24313724 0.24313724 0.25098038 0.24705881 0.23921567
# ...

# %%
# Adicionar uma dimensão para representar o batch
imagem_array = imagem_array.reshape(1, 28, 28, 1)

# Fazer a predição
predicao = modelo.predict(imagem_array)

# Obter o rótulo predito
label_predito = np.argmax(predicao)

# Exibir os resultados
print(f"Predição (valores das probabilidades): {predicao}")
print(f"Rótulo predito: {label_predito}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predição (valores das probabilidades): [[6.0008801e-06 2.2350122e-04 6.5826843e-03 2.0555183e-03 6.1728708e-05
#   4.2863826e-06 9.0919650e-07 9.8948228e-01 1.4046469e-03 1.7844752e-04]]
# Rótulo predito: 7
